# %%
import pandas as pd
import numpy as np

#reading in the merged dataset 

df = pd.read_csv("/Users/xintongtang/Downloads/Archive 2 2/cleaned.csv")
df.head(10)
# Out:
# /Users/xintongtang/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (22) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0  adult                              belongs_to_collection  \
# 0           0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1           1  False                                                NaN
# 2           2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3           3  False                                                NaN
# 4           4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# 5           5  False                                                NaN
# 6           6  False                                                NaN
# 7           7  False                                                NaN
# 8           8  False                                                NaN
# ...

# %%
df = df[df.genres != "[]"]

# %%
df = df[df.imdb_id.str.contains("tt") == True]

# %%
df
# Out:
#        Unnamed: 0  adult                              belongs_to_collection  \
# 0               0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1               1  False                                                NaN
# 2               2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3               3  False                                                NaN
# 4               4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...           ...    ...                                                ...
# 32930       32930  False                                                NaN
# 32931       32931  False                                                NaN
# 32932       32932  False                                                NaN
# 32933       32933  False                                                NaN
# 32934       32934  False                                                NaN
#
# ...

# %%
df.to_csv(r'cleaned2.csv')
