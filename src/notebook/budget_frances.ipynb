# %%
# Import csv
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/FrancesY/Documents/Columbia/spring2022/5063viz/project/data/cleaned2.csv")
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  adult  \
# 0               0             0  False
# 1               1             1  False
# 2               2             2  False
# 3               3             3  False
# 4               4             4  False
# ...           ...           ...    ...
# 31184       32930         32930  False
# 31185       32931         32931  False
# 31186       32932         32932  False
# 31187       32933         32933  False
# 31188       32934         32934  False
#
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 31184                                                NaN         0
# 31185                                                NaN         0
# 31186                                                NaN         0
# 31187                                                NaN         0
# 31188                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 31184  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 31185                     [{'id': 27, 'name': 'Horror'}]
# 31186           [{'id': 878, 'name': 'Science Fiction'}]
# 31187  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 31188  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 31184                                   NaN  390959  tt0265736
# 31185                                   NaN  289923  tt0252966
# 31186                                   NaN  222848  tt0112613
# 31187                                   NaN   30840  tt0102797
# 31188                                   NaN   67758  tt0303758
#
#       original_language  ...  \
# 0                    en  ...
# 1                    en  ...
# 2                    en  ...
# 3                    en  ...
# 4                    en  ...
# ...                 ...  ...
# 31184                en  ...
# 31185                en  ...
# 31186                en  ...
# 31187                en  ...
# 31188                en  ...
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 31184           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31185           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31186           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31187           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31188           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 31184                                                NaN
# 31185  Do you know what happened 50 years before "The...
# 31186                                                NaN
# 31187                                                NaN
# 31188                             A deadly game of wits.
#
#                              title  video vote_average vote_count  \
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 31184    Shadow of the Blair Witch  False          7.0        2.0
# 31185          The Burkittsville 7  False          7.0        1.0
# 31186              Caged Heat 3000  False          3.5        1.0
# 31187                   Robin Hood  False          5.7       26.0
# 31188                     Betrayal  False          3.8        6.0
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 31184  [{'cast_id': 30, 'character': 'Debuty Hank Har...
# 31185  [{'cast_id': 2, 'character': 'Branwall', 'cred...
# 31186  [{'cast_id': 1, 'character': 'Kira (as Cassand...
# 31187  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 31188  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 31184  [{'credit_id': '56ff6ddbc3a3686e9e0013bc', 'de...
# 31185  [{'credit_id': '5403d669c3a3682d9800427d', 'de...
# 31186  [{'credit_id': '5757f36ac3a3687d6f000e8a', 'de...
# 31187  [{'credit_id': '52fe44439251416c9100a899', 'de...
# 31188  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
#
#                                                 keywords
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2      [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4      [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...                                                  ...
# 31184            [{'id': 224180, 'name': 'blair witch'}]
# 31185  [{'id': 616, 'name': 'witch'}, {'id': 2035, 'n...
# 31186                                                 []
# 31187                                                 []
# 31188                                                 []
#
# [31189 rows x 29 columns]

# %%
genres = df['genres']

# %%
genres
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 31184    [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 31185                       [{'id': 27, 'name': 'Horror'}]
# 31186             [{'id': 878, 'name': 'Science Fiction'}]
# 31187    [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 31188    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# Name: genres, Length: 31189, dtype: object

# %%
genres = pd.DataFrame(genres)

# %%
genres['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
# Split by comma
f = lambda x: x["genres"].split(",")
genres = genres.apply(f, axis=1)

# %%
genres = pd.DataFrame(genres)
# Extract first genre
f = lambda x: x[0][1]
genres = genres.apply(f, axis=1)

# %%
genres
# Out:
# 0                'name': 'Animation'}
# 1                'name': 'Adventure'}
# 2                  'name': 'Romance'}
# 3                   'name': 'Comedy'}
# 4                  'name': 'Comedy'}]
#                      ...
# 31184              'name': 'Mystery'}
# 31185              'name': 'Horror'}]
# 31186     'name': 'Science Fiction'}]
# 31187                'name': 'Drama'}
# 31188               'name': 'Action'}
# Length: 31189, dtype: object

# %%
genres = pd.DataFrame(genres)
# Delete 'name'
f = lambda x: str(x[0]).replace("name", "")
genres = genres.apply(f, axis=1)

# %%
genres[0]
# Out:
# " '': 'Animation'}"

# %%
genres = pd.DataFrame(genres)
# Delete '}'
f = lambda x: str(x[0]).replace("}", "")
genres = genres.apply(f, axis=1)

# %%
genres[0]
# Out:
# " '': 'Animation'"

# %%
genres = pd.DataFrame(genres)
# Delete ':'
f = lambda x: str(x[0]).replace(":", "")
genres = genres.apply(f, axis=1)

# %%
genres[0]
# Out:
# " '' 'Animation'"

# %%
genres = pd.DataFrame(genres)
# Delete ' '
f = lambda x: str(x[0]).replace(" ", "")
genres = genres.apply(f, axis=1)

# %%
genres[0]
# Out:
# "'''Animation'"

# %%
genres = pd.DataFrame(genres)
# Delete ']'
f = lambda x: str(x[0]).replace("]", "")
genres = genres.apply(f, axis=1)

# %%
genres[0]
# Out:
# "'''Animation'"

# %%
genres = pd.DataFrame(genres)
# Delete "'"
f = lambda x: str(x[0]).replace("'", "")
genres = genres.apply(f, axis=1)

# %%
genres[0]
# Out:
# 'Animation'

# %%
genres
# Out:
# 0             Animation
# 1             Adventure
# 2               Romance
# 3                Comedy
# 4                Comedy
#               ...
# 31184           Mystery
# 31185            Horror
# 31186    ScienceFiction
# 31187             Drama
# 31188            Action
# Length: 31189, dtype: object

# %%
df['genres'] = genres

# %%
# Drop duplicated columns
df.drop(columns = ["Unnamed: 0","Unnamed: 0.1"], inplace = True)

# %%
# Add release year
df['release_year'] = df['release_date'].str[:4]

# %%
df['release_year'] = pd.to_numeric(df['release_year'])

# %%
# Drop irrelevant columns
df.drop(columns = ["homepage","original_language","spoken_languages","status","poster_path","video"], inplace = True)

# %%
# Showing all the columns
pd.set_option('display.max_columns', None)
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 31184  False                                                NaN         0
# 31185  False                                                NaN         0
# 31186  False                                                NaN         0
# 31187  False                                                NaN         0
# 31188  False                                                NaN         0
#
#                genres      id    imdb_id               original_title  \
# 0           Animation     862  tt0114709                    Toy Story
# 1           Adventure    8844  tt0113497                      Jumanji
# 2             Romance   15602  tt0113228             Grumpier Old Men
# 3              Comedy   31357  tt0114885            Waiting to Exhale
# 4              Comedy   11862  tt0113041  Father of the Bride Part II
# ...               ...     ...        ...                          ...
# 31184         Mystery  390959  tt0265736    Shadow of the Blair Witch
# 31185          Horror  289923  tt0252966          The Burkittsville 7
# 31186  ScienceFiction  222848  tt0112613              Caged Heat 3000
# 31187           Drama   30840  tt0102797                   Robin Hood
# 31188          Action   67758  tt0303758                     Betrayal
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 31184  In this true-crime documentary, we delve into ...    0.076061
# 31185  A film archivist revisits the story of Rustin ...    0.386450
# 31186  It's the year 3000 AD. The world's most danger...    0.661558
# 31187  Yet another version of the classic epic, with ...    5.683753
# 31188  When one of her hits goes wrong, a professiona...    0.903007
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 31184                                                 []
# 31185  [{'name': 'Neptune Salad Entertainment', 'id':...
# 31186    [{'name': 'Concorde-New Horizons', 'id': 4688}]
# 31187  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 31188  [{'name': 'American World Pictures', 'id': 6165}]
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 31184                                                 []   2000-10-22
# 31185  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-10-03
# 31186  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-01-01
# 31187  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 31188  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 31184          0.0     45.0
# 31185          0.0     30.0
# 31186          0.0     85.0
# 31187          0.0    104.0
# 31188          0.0     90.0
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 31184                                                NaN
# 31185  Do you know what happened 50 years before "The...
# 31186                                                NaN
# 31187                                                NaN
# 31188                             A deadly game of wits.
#
#                              title  vote_average  vote_count  \
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 31184    Shadow of the Blair Witch           7.0         2.0
# 31185          The Burkittsville 7           7.0         1.0
# 31186              Caged Heat 3000           3.5         1.0
# 31187                   Robin Hood           5.7        26.0
# 31188                     Betrayal           3.8         6.0
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 31184  [{'cast_id': 30, 'character': 'Debuty Hank Har...
# 31185  [{'cast_id': 2, 'character': 'Branwall', 'cred...
# 31186  [{'cast_id': 1, 'character': 'Kira (as Cassand...
# 31187  [{'cast_id': 1, 'character': 'Sir Robert Hode'...
# 31188  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 31184  [{'credit_id': '56ff6ddbc3a3686e9e0013bc', 'de...
# 31185  [{'credit_id': '5403d669c3a3682d9800427d', 'de...
# 31186  [{'credit_id': '5757f36ac3a3687d6f000e8a', 'de...
# 31187  [{'credit_id': '52fe44439251416c9100a899', 'de...
# 31188  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
#
#                                                 keywords  release_year
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...        1995.0
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...        1995.0
# 2      [{'id': 1495, 'name': 'fishing'}, {'id': 12392...        1995.0
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...        1995.0
# 4      [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...        1995.0
# ...                                                  ...           ...
# 31184            [{'id': 224180, 'name': 'blair witch'}]        2000.0
# 31185  [{'id': 616, 'name': 'witch'}, {'id': 2035, 'n...        2000.0
# 31186                                                 []        1995.0
# 31187                                                 []        1991.0
# 31188                                                 []        2003.0
#
# [31189 rows x 22 columns]

# %%
# Drop rows with 0 budget
df2 = df[df['budget'] != 0]

# %%
# Drop rows with 0 revenue
df3 = df2[df2['revenue'] != 0]

# %%
# Set budget and revenue to at least $1000
df4 = df3[df3['budget'] > 1000]
df5 = df4[df4['revenue'] > 1000]

# %%
df5
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 3      False                                                NaN  16000000
# 5      False                                                NaN  60000000
# 8      False                                                NaN  35000000
# ...      ...                                                ...       ...
# 30970  False                                                NaN  60000000
# 31029  False                                                NaN  50000000
# 31044  False                                                NaN  11000000
# 31154  False                                                NaN    800000
# 31156  False                                                NaN   2000000
#
#           genres      id    imdb_id     original_title  \
# 0      Animation     862  tt0114709          Toy Story
# 1      Adventure    8844  tt0113497            Jumanji
# 3         Comedy   31357  tt0114885  Waiting to Exhale
# 5         Action     949  tt0113277               Heat
# 8         Action    9091  tt0114576       Sudden Death
# ...          ...     ...        ...                ...
# 30970     Action  353491  tt1648190     The Dark Tower
# 31029     Comedy  378236  tt4877122    The Emoji Movie
# 31044     Action  395834  tt5362988         Wind River
# 31154     Comedy   62757  tt0933361             Dikari
# 31156    Romance   63281  tt1718881         Про любоff
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 5      Obsessive master thief, Neil McCauley leads a ...   17.924927
# 8      International action superstar Jean Claude Van...    5.231580
# ...                                                  ...         ...
# 30970  The last Gunslinger, Roland Deschain, has been...   50.903593
# 31029  Gene, a multi-expressional emoji, sets out on ...   33.694599
# 31044  An FBI agent teams with the town's veteran gam...   40.796775
# 31154  The sea, August, interesting and simple people...    0.903061
# 31156  У девушки Даши, приехавшей с подругой «покорят...    0.121844
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 5      [{'name': 'Regency Enterprises', 'id': 508}, {...
# 8      [{'name': 'Universal Pictures', 'id': 33}, {'n...
# ...                                                  ...
# 30970  [{'name': 'Imagine Entertainment', 'id': 23}, ...
# 31029  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 31044  [{'name': 'Thunder Road Pictures', 'id': 3528}...
# 31154                                                 []
# 31156                  [{'name': 'Profit', 'id': 21163}]
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 5      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 8      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# ...                                                  ...          ...
# 30970  [{'iso_3166_1': 'ZA', 'name': 'South Africa'},...   2017-08-03
# 31029  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-07-28
# 31044  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-08-03
# 31154                                                 []   2006-11-23
# 31156           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   2010-09-30
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 3       81452156.0    127.0
# 5      187436818.0    170.0
# 8       64350171.0    106.0
# ...            ...      ...
# 30970   71000000.0     95.0
# 31029   66913939.0     86.0
# 31044  184770205.0    111.0
# 31154    1328612.0    100.0
# 31156    1268793.0    107.0
#
#                                                  tagline              title  \
# 0                                                    NaN          Toy Story
# 1              Roll the dice and unleash the excitement!            Jumanji
# 3      Friends are the people who let you be yourself...  Waiting to Exhale
# 5                               A Los Angeles Crime Saga               Heat
# 8                             Terror goes into overtime.       Sudden Death
# ...                                                  ...                ...
# 30970                  There are other worlds than these     The Dark Tower
# 31029                                 Not easy being meh    The Emoji Movie
# 31044         Nothing is harder to track than the truth.         Wind River
# 31154                                                NaN            Savages
# 31156                                                NaN        Pro Lyuboff
#
#        vote_average  vote_count  \
# 0               7.7        5415
# 1               6.9        2413
# 3               6.1          34
# 5               7.7        1886
# 8               5.5         174
# ...             ...         ...
# 30970           5.7         688
# 31029           5.8         327
# 31044           7.4         181
# 31154           5.8           6
# 31156           4.0           3
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 5      [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 8      [{'cast_id': 1, 'character': 'Darren Francis T...
# ...                                                  ...
# 30970  [{'cast_id': 9, 'character': 'Roland Deschain'...
# 31029  [{'cast_id': 2, 'character': 'Gene (voice)', '...
# 31044  [{'cast_id': 9, 'character': 'Cory Lambert', '...
# 31154  [{'cast_id': 1001, 'character': 'Mister', 'cre...
# 31156  [{'cast_id': 1001, 'character': 'Vlad', 'credi...
#
#                                                     crew  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 5      [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 8      [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...
# ...                                                  ...
# 30970  [{'credit_id': '5912cf71c3a36864d40533b7', 'de...
# 31029  [{'credit_id': '5952d8f1c3a368151c025d0e', 'de...
# 31044  [{'credit_id': '572815d0c3a3687a00001314', 'de...
# 31154  [{'credit_id': '52fe468cc3a368484e096ba7', 'de...
# 31156  [{'credit_id': '52fe46a3c3a368484e09b9fd', 'de...
#
#                                                 keywords  release_year
# 0      [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...        1995.0
# 1      [{'id': 10090, 'name': 'board game'}, {'id': 1...        1995.0
# 3      [{'id': 818, 'name': 'based on novel'}, {'id':...        1995.0
# 5      [{'id': 642, 'name': 'robbery'}, {'id': 703, '...        1995.0
# 8      [{'id': 949, 'name': 'terrorist'}, {'id': 1562...        1995.0
# ...                                                  ...           ...
# 30970  [{'id': 75, 'name': 'gunslinger'}, {'id': 818,...        2017.0
# 31029  [{'id': 207468, 'name': 'app'}, {'id': 229979,...        2017.0
# 31044  [{'id': 570, 'name': 'rape'}, {'id': 1262, 'na...        2017.0
# 31154                                                 []        2006.0
# 31156                                                 []        2010.0
#
# [4779 rows x 22 columns]
